# %% [markdown]
# # Hadoop Streaming assignment 4: Word Groups

# %% [markdown]
# Calculate statistics for groups of words which are equal up to permutations of letters. For example, ‘emit’, ‘item’ and ‘time’ are the same words up to a permutation of letters. Determine such groups of words and sum all their counts. Apply stop words filter. Filter out groups that consist of only one word.
#
# Output: count of occurrences for the group of words, number of unique words in the group, comma-separated list of the words in the group in lexicographical order:
#
#     sum <tab> group size <tab> word1,word2,...
#
# Example: assume ‘emit’ occurred 3 times, 'item' -- 2 times, 'time' -- 5 times; 3 + 2 + 5 = 10, group contains 3 words, so for this group result is:
#
#     10 3 emit,item,time
#
# The result of the task is the output line with word ‘english’.
#
# The result on the sample dataset:
#
#
# `7823    eghilns 5   english,helsing,hesling,shengli,shingle`
#
# NB: Do not forget about the lexicographical order of words in the group: 'emit,item,time' is OK, 'emit,time,item' is not.

# %%
# %config IPCompleter.greedy=True

# %% [markdown]
# ## Step 1. Create the 1st mapper and reducer

# %%
# %%writefile mapper1.py

import sys
import re

reload(sys)
sys.setdefaultencoding('utf-8')  # required to convert to unicode

path = 'stop_words_en.txt'

# Your code for reading stop words here
with open(path, "r") as f:
    stop_words = f.read().split('\n')

for line in sys.stdin:
    try:
        article_id, text = unicode(line.strip()).split('\t', 1)
    except ValueError as e:
        continue

    words = re.split("\W*\s+\W*", text, flags=re.UNICODE)
    words = [word for word in words if (word not in stop_words) and word.isalpha()]
    # Your code for mapper here.
    for word in words:
        print >> sys.stderr, "reporter:counter:Wiki stats,Total words,%d" % 1
        print "%s\t%d" % (word.lower(), 1)
# Out:
# Overwriting mapper1.py

# %%
# %%writefile reducer1.py

# Your code for reducer here.
import sys

current_key = None
total_words = 0

for line in sys.stdin:
    try:
        key, count = line.strip().split('\t', 1)
        count = int(count)
    except ValueError as e:
        continue
    if key != current_key:
        if current_key:
            print("{0}\t{1}".format(current_key, total_words))
        total_words = 0
        current_key = key
    total_words += count
if current_key:
    print("{0}\t{1}".format(current_key, total_words))
# Out:
# Overwriting reducer1.py

# %% [markdown]
# ## Step 2. Create the 2nd mapper and reducer

# %%
# %%writefile mapper2.py

import sys

current_key = None
sorted_key = None
total_words = 0

for line in sys.stdin:
    try:
        key, count = line.strip().split('\t', 1)
        count = int(count)
    except ValueError as e:
        continue
    
    if key != current_key:
        if current_key:
            print("{0}\t{1}\t{2}".format(sorted_key, current_key, total_words))
        total_words = 0
        current_key = key
        # .join(['a','e','l','p','p'])
        sorted_key = "".join(sorted(current_key))
    total_words += count
    
if current_key:
    print("{0}\t{1}\t{2}".format(sorted_key, current_key, total_words))
# Out:
# Writing mapper2.py

# %%
# %%writefile reducer2.py

import sys

word_set = ()
current_key = None
total_words = 0

for line in sys.stdin:
    try:
        sorted_key, key, count = line.strip().split('\t', 2)
        count = int(count)
    except ValueError as e:
        continue
    if current_key != sorted_key:
        if current_key:
            #7823    eghilns 5   english,helsing,hesling,shengli,shingle
            print("{0}\t{1}\t{2}\t{3}".format(total_words, current_key, len(word_set), ",".join(sorted(word_set))))
            
        total_words = 0
        current_key = sorted_key
        word_set = ()
        
    word_set.add(key)
    total_words += count
    
if current_key:
    print("{0}\t{1}\t{2}\t{3}".format(total_words, current_key, len(word_set), ",".join(sorted(word_set))))
# Out:
# Writing reducer2.py

# %% [markdown]
# ## Step 3. Bash command

# %% [markdown]
# Hint: For printing the exact row you may use basic UNIX commands. For instance, sed/head/tail/... (if you know other commands, you can use them).
#
# To run both jobs, you must use two consecutive yarn-commands. Remember that the input for the second job is the ouput for the first job.

# %%
# %%bash
#
# OUT_DIR_1="assignment4_1_"$(date +"%s%6N")
# OUT_DIR_2="assignment4_2_"$(date +"%s%6N")
# NUM_REDUCERS=4
#
# # Code for your first job
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -files mapper1.py,reducer1.py,/datasets/stop_words_en.txt \
#     -mapper 'python mapper1.py' \
#     -combiner 'python reducer1.py' \
#     -reducer 'python reducer1.py' \
#     -numReduceTasks ${NUM_REDUCERS} \
#     -input /data/wiki/en_articles_part \
#     -output ${OUT_DIR_1} > /dev/null
#
#
# # Code for your second job
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -files mapper2.py,reducer2.py \
#     -mapper 'python mapper2.py' \
#     -reducer 'python reducer2.py' \
#     -numReduceTasks 1 \
#     -input ${OUT_DIR_1} \
#     -output ${OUT_DIR_2} > /dev/null
#
# # Code for obtaining the results
# hdfs dfs -cat ${OUT_DIR_2}/part-00000 | grep "english,"
#
# hdfs dfs -rm -r -skipTrash ${OUT_DIR_1}* > /dev/null
# hdfs dfs -rm -r -skipTrash ${OUT_DIR_2}* > /dev/null
# Out:
# 19/05/21 04:57:19 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 19/05/21 04:57:19 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 19/05/21 04:57:21 INFO mapred.FileInputFormat: Total input files to process : 1
# 19/05/21 04:57:21 INFO mapreduce.JobSubmitter: number of splits:2
# 19/05/21 04:57:21 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1558306547568_0001
# 19/05/21 04:57:22 INFO impl.YarnClientImpl: Submitted application application_1558306547568_0001
# 19/05/21 04:57:22 INFO mapreduce.Job: The url to track the job: http://994ded922800:8088/proxy/application_1558306547568_0001/
# 19/05/21 04:57:22 INFO mapreduce.Job: Running job: job_1558306547568_0001
# 19/05/21 04:57:29 INFO mapreduce.Job: Job job_1558306547568_0001 running in uber mode : false
# 19/05/21 04:57:29 INFO mapreduce.Job:  map 0% reduce 0%
# 19/05/21 04:57:45 INFO mapreduce.Job:  map 3% reduce 0%
# 19/05/21 04:57:51 INFO mapreduce.Job:  map 4% reduce 0%
# 19/05/21 04:57:57 INFO mapreduce.Job:  map 6% reduce 0%
# 19/05/21 04:58:03 INFO mapreduce.Job:  map 7% reduce 0%
# 19/05/21 04:58:09 INFO mapreduce.Job:  map 9% reduce 0%
# 19/05/21 04:58:15 INFO mapreduce.Job:  map 10% reduce 0%
# 19/05/21 04:58:21 INFO mapreduce.Job:  map 11% reduce 0%
# 19/05/21 04:58:27 INFO mapreduce.Job:  map 13% reduce 0%
# 19/05/21 04:58:33 INFO mapreduce.Job:  map 14% reduce 0%
# 19/05/21 04:58:39 INFO mapreduce.Job:  map 16% reduce 0%
# 19/05/21 04:58:45 INFO mapreduce.Job:  map 17% reduce 0%
# 19/05/21 04:58:51 INFO mapreduce.Job:  map 18% reduce 0%
# 19/05/21 04:58:57 INFO mapreduce.Job:  map 20% reduce 0%
# 19/05/21 04:59:03 INFO mapreduce.Job:  map 21% reduce 0%
# 19/05/21 04:59:09 INFO mapreduce.Job:  map 23% reduce 0%
# 19/05/21 04:59:15 INFO mapreduce.Job:  map 24% reduce 0%
# 19/05/21 04:59:21 INFO mapreduce.Job:  map 25% reduce 0%
# 19/05/21 04:59:27 INFO mapreduce.Job:  map 27% reduce 0%
# 19/05/21 04:59:33 INFO mapreduce.Job:  map 28% reduce 0%
# 19/05/21 04:59:39 INFO mapreduce.Job:  map 29% reduce 0%
# 19/05/21 04:59:45 INFO mapreduce.Job:  map 31% reduce 0%
# 19/05/21 04:59:51 INFO mapreduce.Job:  map 32% reduce 0%
# 19/05/21 04:59:57 INFO mapreduce.Job:  map 34% reduce 0%
# 19/05/21 05:00:03 INFO mapreduce.Job:  map 35% reduce 0%
# 19/05/21 05:00:09 INFO mapreduce.Job:  map 36% reduce 0%
# 19/05/21 05:00:15 INFO mapreduce.Job:  map 38% reduce 0%
# 19/05/21 05:00:21 INFO mapreduce.Job:  map 39% reduce 0%
# 19/05/21 05:00:27 INFO mapreduce.Job:  map 41% reduce 0%
# 19/05/21 05:00:33 INFO mapreduce.Job:  map 42% reduce 0%
# 19/05/21 05:00:39 INFO mapreduce.Job:  map 43% reduce 0%
# 19/05/21 05:00:45 INFO mapreduce.Job:  map 45% reduce 0%
# 19/05/21 05:00:51 INFO mapreduce.Job:  map 46% reduce 0%
# 19/05/21 05:00:57 INFO mapreduce.Job:  map 48% reduce 0%
# 19/05/21 05:01:03 INFO mapreduce.Job:  map 49% reduce 0%
# 19/05/21 05:01:10 INFO mapreduce.Job:  map 50% reduce 0%
# 19/05/21 05:01:16 INFO mapreduce.Job:  map 52% reduce 0%
# 19/05/21 05:01:22 INFO mapreduce.Job:  map 53% reduce 0%
# 19/05/21 05:01:28 INFO mapreduce.Job:  map 54% reduce 0%
# 19/05/21 05:01:34 INFO mapreduce.Job:  map 56% reduce 0%
# 19/05/21 05:01:40 INFO mapreduce.Job:  map 57% reduce 0%
# 19/05/21 05:01:46 INFO mapreduce.Job:  map 59% reduce 0%
# 19/05/21 05:01:52 INFO mapreduce.Job:  map 60% reduce 0%
# 19/05/21 05:01:58 INFO mapreduce.Job:  map 61% reduce 0%
# 19/05/21 05:02:04 INFO mapreduce.Job:  map 63% reduce 0%
# 19/05/21 05:02:10 INFO mapreduce.Job:  map 64% reduce 0%
# 19/05/21 05:02:16 INFO mapreduce.Job:  map 66% reduce 0%
# 19/05/21 05:02:25 INFO mapreduce.Job:  map 83% reduce 0%
# 19/05/21 05:02:30 INFO mapreduce.Job:  map 100% reduce 0%
# 19/05/21 05:02:31 INFO mapreduce.Job:  map 100% reduce 25%
# 19/05/21 05:02:32 INFO mapreduce.Job:  map 100% reduce 75%
# 19/05/21 05:02:33 INFO mapreduce.Job:  map 100% reduce 100%
# 19/05/21 05:02:34 INFO mapreduce.Job: Job job_1558306547568_0001 completed successfully
# 19/05/21 05:02:34 INFO mapreduce.Job: Counters: 51
# 	File System Counters
# 		FILE: Number of bytes read=8822141
# 		FILE: Number of bytes written=14048060
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=76874501
# 		HDFS: Number of bytes written=2791807
# 		HDFS: Number of read operations=18
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=8
# 	Job Counters
# 		Launched map tasks=2
# 		Launched reduce tasks=4
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=592309
# 		Total time spent by all reduces in occupied slots (ms)=14539
# 		Total time spent by all map tasks (ms)=592309
# 		Total time spent by all reduce tasks (ms)=14539
# 		Total vcore-milliseconds taken by all map tasks=592309
# 		Total vcore-milliseconds taken by all reduce tasks=14539
# 		Total megabyte-milliseconds taken by all map tasks=606524416
# 		Total megabyte-milliseconds taken by all reduce tasks=14887936
# 	Map-Reduce Framework
# 		Map input records=4100
# 		Map output records=6603719
# 		Map output bytes=63353178
# 		Map output materialized bytes=4402396
# 		Input split bytes=228
# 		Combine input records=6603719
# 		Combine output records=331473
# 		Reduce input groups=243470
# 		Reduce shuffle bytes=4402396
# 		Reduce input records=331473
# 		Reduce output records=243470
# 		Spilled Records=994419
# 		Shuffled Maps =8
# 		Failed Shuffles=0
# 		Merged Map outputs=8
# 		GC time elapsed (ms)=880
# 		CPU time spent (ms)=701240
# 		Physical memory (bytes) snapshot=1358925824
# 		Virtual memory (bytes) snapshot=12116725760
# 		Total committed heap usage (bytes)=914358272
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	Wiki stats
# 		Stop words=377490
# 		Total words=6603719
# 	File Input Format Counters
# 		Bytes Read=76874273
# 	File Output Format Counters
# 		Bytes Written=2791807
# 19/05/21 05:02:34 INFO streaming.StreamJob: Output directory: assignment4_1_1558414637429818
# 19/05/21 05:02:36 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 19/05/21 05:02:36 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 19/05/21 05:02:36 INFO mapred.FileInputFormat: Total input files to process : 4
# 19/05/21 05:02:37 INFO mapreduce.JobSubmitter: number of splits:4
# 19/05/21 05:02:37 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1558306547568_0002
# 19/05/21 05:02:37 INFO impl.YarnClientImpl: Submitted application application_1558306547568_0002
# 19/05/21 05:02:37 INFO mapreduce.Job: The url to track the job: http://994ded922800:8088/proxy/application_1558306547568_0002/
# 19/05/21 05:02:37 INFO mapreduce.Job: Running job: job_1558306547568_0002
# 19/05/21 05:02:45 INFO mapreduce.Job: Job job_1558306547568_0002 running in uber mode : false
# 19/05/21 05:02:45 INFO mapreduce.Job:  map 0% reduce 0%
# 19/05/21 05:02:50 INFO mapreduce.Job:  map 100% reduce 0%
# 19/05/21 05:02:53 INFO mapreduce.Job: Task Id : attempt_1558306547568_0002_r_000000_0, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:250)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:459)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:392)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1807)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 19/05/21 05:02:58 INFO mapreduce.Job: Task Id : attempt_1558306547568_0002_r_000000_1, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:250)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:459)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:392)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1807)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 19/05/21 05:03:03 INFO mapreduce.Job: Task Id : attempt_1558306547568_0002_r_000000_2, Status : FAILED
# Error: java.lang.RuntimeException: PipeMapRed.waitOutputThreads(): subprocess failed with code 1
# 	at org.apache.hadoop.streaming.PipeMapRed.waitOutputThreads(PipeMapRed.java:325)
# 	at org.apache.hadoop.streaming.PipeMapRed.mapRedFinished(PipeMapRed.java:538)
# 	at org.apache.hadoop.streaming.PipeReducer.close(PipeReducer.java:134)
# 	at org.apache.hadoop.io.IOUtils.cleanup(IOUtils.java:250)
# 	at org.apache.hadoop.mapred.ReduceTask.runOldReducer(ReduceTask.java:459)
# 	at org.apache.hadoop.mapred.ReduceTask.run(ReduceTask.java:392)
# 	at org.apache.hadoop.mapred.YarnChild$2.run(YarnChild.java:175)
# 	at java.security.AccessController.doPrivileged(Native Method)
# 	at javax.security.auth.Subject.doAs(Subject.java:422)
# 	at org.apache.hadoop.security.UserGroupInformation.doAs(UserGroupInformation.java:1807)
# 	at org.apache.hadoop.mapred.YarnChild.main(YarnChild.java:169)
#
# 19/05/21 05:03:10 INFO mapreduce.Job:  map 100% reduce 100%
# 19/05/21 05:03:11 INFO mapreduce.Job: Job job_1558306547568_0002 failed with state FAILED due to: Task failed task_1558306547568_0002_r_000000
# Job failed as tasks failed. failedMaps:0 failedReduces:1
#
# 19/05/21 05:03:11 INFO mapreduce.Job: Counters: 37
# 	File System Counters
# 		FILE: Number of bytes read=0
# 		FILE: Number of bytes written=6091318
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=2792315
# 		HDFS: Number of bytes written=0
# 		HDFS: Number of read operations=12
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=0
# 	Job Counters
# 		Failed reduce tasks=4
# 		Launched map tasks=4
# 		Launched reduce tasks=4
# 		Data-local map tasks=4
# 		Total time spent by all maps in occupied slots (ms)=11265
# 		Total time spent by all reduces in occupied slots (ms)=9805
# 		Total time spent by all map tasks (ms)=11265
# 		Total time spent by all reduce tasks (ms)=9805
# 		Total vcore-milliseconds taken by all map tasks=11265
# 		Total vcore-milliseconds taken by all reduce tasks=9805
# 		Total megabyte-milliseconds taken by all map tasks=11535360
# 		Total megabyte-milliseconds taken by all reduce tasks=10040320
# 	Map-Reduce Framework
# 		Map input records=243470
# 		Map output records=243470
# 		Map output bytes=5046206
# 		Map output materialized bytes=5533170
# 		Input split bytes=508
# 		Combine input records=0
# 		Spilled Records=243470
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=297
# 		CPU time spent (ms)=5580
# 		Physical memory (bytes) snapshot=1143738368
# 		Virtual memory (bytes) snapshot=8035975168
# 		Total committed heap usage (bytes)=805306368
# 	File Input Format Counters
# 		Bytes Read=2791807
# 19/05/21 05:03:11 ERROR streaming.StreamJob: Job not successful!
# Streaming Command Failed!
# cat: `assignment4_2_1558414637431408/part-00000': No such file or directory
